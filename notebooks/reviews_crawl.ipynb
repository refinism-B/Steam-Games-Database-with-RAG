# %% [markdown]
# ## 評論爬蟲

# %%
import json
import time
from datetime import datetime
from pathlib import Path

import requests

from src.config.constant import (RAW_GAME_ID_SUBFOLDER,
                                 RAW_GAME_REVIEWS_SUBFOLDER,
                                 RAW_REVIEW_METADATA_SUBFOLDER)

# %%
# raw_sub_folder = RAW_GAME_ID_SUBFOLDER
# root = Path(__file__).resolve().parents[2]
# raw_folder = root / raw_sub_folder

# %%
id_file_num = 1
id_folder = Path(
    r"C:\Users\add41\Documents\Data_Engineer\Project\Steam-Games-Database-with-RAG\data\raw\game_id")
review_file_num = 1
review_folder = Path(
    r"C:\Users\add41\Documents\Data_Engineer\Project\Steam-Games-Database-with-RAG\data\raw\game_review")

review_list = []
data_count = 0
failed_list = []
failed_count = 0

max_result = 2000
tries = 1
last_id = None

now_date = datetime.now().strftime("%Y-%m-%d")
start_time = datetime.now().strftime("%H:%M:%S")


while True:
    id_file = f"game_id_{id_file_num}.json"
    id_path = id_folder / id_file

    if not id_path.exists():
        search_result = True
        break

    with open(id_path, 'r', encoding='utf-8') as f:
        game_list_data = json.load(f)

    print(f"開始讀取{id_file}資料...")
    game_list = game_list_data.get("data")

    for game in game_list:
        tries = 1
        print(f"[{id_file}]開始搜尋第{data_count+1}筆資料...")

        app_id = game.get("appid")
        url = f"https://store.steampowered.com/appreviews/{app_id}?json=1&language=all"

        while tries <= 5:
            try:
                res = requests.get(url)

                review_data = res.json()
                review_list.append(review_data)
                last_id = app_id

                now_time = datetime.now().strftime("%H:%M:%S")
                data = {
                    "update_date": now_date,
                    "update_time": now_time,
                    "data": review_list
                }

                review_file = f"game_review_{review_file_num}.json"
                info_save_path = review_folder / review_file

                with open(info_save_path, 'w', encoding='utf-8') as f:
                    json.dump(data, f, ensure_ascii=False, indent=2)

                data_count += 1
                print(f"[{id_file}]第{data_count}筆資料儲存完畢！")
                time.sleep(2)

                if len(review_list) >= max_result:
                    review_file_num += 1
                    review_list.clear()

                break

            except Exception as e:
                print(f"資料爬取發生錯誤: {e}")
                if tries < 5:
                    print(f"等待{tries*10}秒後再次繼續...")
                    time.sleep(tries*10)
                    tries += 1
                    continue
                else:
                    print("已達重試次數上限，跳過此筆資料")
                    failed_count += 1
                    failed_list.append(app_id)
                    break

    id_file_num += 1


now_date_filename = datetime.now().strftime("%Y%m%d")
end_time = datetime.now().strftime("%H:%M:%S")

metadata = {
    "update_date": now_date,
    "start_time": start_time,
    "end_time": end_time,
    "failed_count": failed_count,
    "failed_list": failed_list,
    "data_count": data_count,
    "last_appid": last_id
}

metadata_folder = Path(
    r"C:\Users\add41\Documents\Data_Engineer\Project\Steam-Games-Database-with-RAG\data\raw\game_review\metadata")
metadata_file = f"{now_date_filename}_metadata_game_review.json"
metadata_path = metadata_folder / metadata_file

with open(metadata_path, 'w', encoding='utf-8') as f:
    json.dump(metadata, f, ensure_ascii=False, indent=2)
# Out:
# 開始讀取game_id_1.json資料...
# [game_id_1.json]開始搜尋第1筆資料...
# [game_id_1.json]第1筆資料儲存完畢！
# [game_id_1.json]開始搜尋第2筆資料...
# [game_id_1.json]第2筆資料儲存完畢！
# [game_id_1.json]開始搜尋第3筆資料...
# [game_id_1.json]第3筆資料儲存完畢！
# [game_id_1.json]開始搜尋第4筆資料...
# [game_id_1.json]第4筆資料儲存完畢！
# [game_id_1.json]開始搜尋第5筆資料...
# [game_id_1.json]第5筆資料儲存完畢！
# [game_id_1.json]開始搜尋第6筆資料...
# [game_id_1.json]第6筆資料儲存完畢！
# [game_id_1.json]開始搜尋第7筆資料...
# [game_id_1.json]第7筆資料儲存完畢！
# [game_id_1.json]開始搜尋第8筆資料...
# [game_id_1.json]第8筆資料儲存完畢！
# [game_id_1.json]開始搜尋第9筆資料...
# [game_id_1.json]第9筆資料儲存完畢！
# [game_id_1.json]開始搜尋第10筆資料...
# [game_id_1.json]第10筆資料儲存完畢！
# [game_id_1.json]開始搜尋第11筆資料...
# [game_id_1.json]第11筆資料儲存完畢！
# [game_id_1.json]開始搜尋第12筆資料...
# [game_id_1.json]第12筆資料儲存完畢！
# [game_id_1.json]開始搜尋第13筆資料...
# [game_id_1.json]第13筆資料儲存完畢！
# [game_id_1.json]開始搜尋第14筆資料...
# [game_id_1.json]第14筆資料儲存完畢！
# [game_id_1.json]開始搜尋第15筆資料...
# [game_id_1.json]第15筆資料儲存完畢！
# [game_id_1.json]開始搜尋第16筆資料...
# [game_id_1.json]第16筆資料儲存完畢！
# [game_id_1.json]開始搜尋第17筆資料...
# [game_id_1.json]第17筆資料儲存完畢！
# [game_id_1.json]開始搜尋第18筆資料...
# [game_id_1.json]第18筆資料儲存完畢！
# [game_id_1.json]開始搜尋第19筆資料...
# [game_id_1.json]第19筆資料儲存完畢！
# [game_id_1.json]開始搜尋第20筆資料...
# [game_id_1.json]第20筆資料儲存完畢！
# [game_id_1.json]開始搜尋第21筆資料...
# [game_id_1.json]第21筆資料儲存完畢！
# [game_id_1.json]開始搜尋第22筆資料...
# [game_id_1.json]第22筆資料儲存完畢！
# [game_id_1.json]開始搜尋第23筆資料...
# [game_id_1.json]第23筆資料儲存完畢！
# [game_id_1.json]開始搜尋第24筆資料...
# [game_id_1.json]第24筆資料儲存完畢！
# [game_id_1.json]開始搜尋第25筆資料...
# [game_id_1.json]第25筆資料儲存完畢！
# [game_id_1.json]開始搜尋第26筆資料...
# [game_id_1.json]第26筆資料儲存完畢！
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 65
#      63 data_count += 1
#      64 print(f"[{id_file}]第{data_count}筆資料儲存完畢！")
# ---> 65 time.sleep(2)
#      67 if len(review_list) >= max_result:
#      68     review_file_num += 1
#
# KeyboardInterrupt:

# %%
url = "https://store.steampowered.com/appreviews/{}?json=1&language=all&num_per_page=0"
app_id = "10"

res = requests.get(url.format(app_id))

i = res.json()
i["appid"] = app_id
i
# Out:
# {'success': 1,
#  'query_summary': {'num_reviews': 0,
#   'review_score': 9,
#   'review_score_desc': 'Overwhelmingly Positive',
#   'total_positive': 160203,
#   'total_negative': 4982,
#   'total_reviews': 165185},
#  'reviews': [],
#  'cursor': '*',
#  'appid': '10'}

# %% [markdown]
# ## 標籤爬蟲

# %%
id_file_num = 1
id_folder = Path(
    r"C:\Users\add41\Documents\Data_Engineer\Project\Steam-Games-Database-with-RAG\data\raw\game_id")
tag_file_num = 1
tag_folder = Path(
    r"C:\Users\add41\Documents\Data_Engineer\Project\Steam-Games-Database-with-RAG\data\raw\game_tag")

tag_list = []
data_count = 0
failed_list = []
failed_count = 0

max_result = 2000
tries = 1
last_id = None

now_date = datetime.now().strftime("%Y-%m-%d")
start_time = datetime.now().strftime("%H:%M:%S")


while True:
    id_file = f"game_id_{id_file_num}.json"
    id_path = id_folder / id_file

    if not id_path.exists():
        search_result = True
        break

    with open(id_path, 'r', encoding='utf-8') as f:
        game_list_data = json.load(f)

    print(f"開始讀取{id_file}資料...")
    game_list = game_list_data.get("data")

    for game in game_list:
        tries = 1
        print(f"[{id_file}]開始搜尋第{data_count+1}筆資料...")

        app_id = game.get("appid")
        url = f"https://steamspy.com/api.php?request=appdetails&appid={app_id}"

        while tries <= 5:
            try:
                res = requests.get(url)

                tag_data = res.json()
                tag_list.append(tag_data)
                last_id = app_id

                now_time = datetime.now().strftime("%H:%M:%S")
                data = {
                    "update_date": now_date,
                    "update_time": now_time,
                    "data": tag_list
                }

                tag_file = f"game_tag_{tag_file_num}.json"
                tag_save_path = tag_folder / tag_file

                with open(tag_save_path, 'w', encoding='utf-8') as f:
                    json.dump(data, f, ensure_ascii=False, indent=2)

                data_count += 1
                print(f"[{id_file}]第{data_count}筆資料儲存完畢！")
                time.sleep(2)

                if len(tag_list) >= max_result:
                    tag_file_num += 1
                    tag_list.clear()

                break

            except Exception as e:
                print(f"資料爬取發生錯誤: {e}")
                if tries < 5:
                    print(f"等待{tries*10}秒後再次繼續...")
                    time.sleep(tries*10)
                    tries += 1
                    continue
                else:
                    print("已達重試次數上限，跳過此筆資料")
                    failed_count += 1
                    failed_list.append(app_id)
                    break

    id_file_num += 1


now_date_filename = datetime.now().strftime("%Y%m%d")
end_time = datetime.now().strftime("%H:%M:%S")

metadata = {
    "update_date": now_date,
    "start_time": start_time,
    "end_time": end_time,
    "failed_count": failed_count,
    "failed_list": failed_list,
    "data_count": data_count,
    "last_appid": last_id
}

metadata_folder = Path(
    r"C:\Users\add41\Documents\Data_Engineer\Project\Steam-Games-Database-with-RAG\data\raw\game_tag\metadata")
metadata_file = f"{now_date_filename}_metadata_game_tag.json"
metadata_path = metadata_folder / metadata_file

with open(metadata_path, 'w', encoding='utf-8') as f:
    json.dump(metadata, f, ensure_ascii=False, indent=2)

# %%
url = "https://steamspy.com/api.php?request=appdetails&appid={}"
app_id = "10"

res = requests.get(url.format(app_id))

res.json()
# Out:
# {'appid': 10,
#  'name': 'Counter-Strike',
#  'developer': 'Valve',
#  'publisher': 'Valve',
#  'score_rank': '',
#  'positive': 243818,
#  'negative': 6427,
#  'userscore': 0,
#  'owners': '10,000,000 .. 20,000,000',
#  'average_forever': 10195,
#  'average_2weeks': 502,
#  'median_forever': 176,
#  'median_2weeks': 31,
#  'price': '999',
#  'initialprice': '999',
#  'discount': '0',
#  'ccu': 7323,
#  'languages': 'English, French, German, Italian, Spanish - Spain, Simplified Chinese, Traditional Chinese, Korean',
#  'genre': 'Action',
#  'tags': {'Action': 5504,
#   'FPS': 4929,
#   'Multiplayer': 3474,
#   'Shooter': 3419,
#   'Classic': 2849,
#   'Team-Based': 1921,
#   'First-Person': 1761,
#   'Competitive': 1654,
#   'Tactical': 1391,
#   "1990's": 1246,
#   'e-sports': 1232,
#   'PvP': 928,
#   'Old School': 829,
#   'Military': 665,
#   'Strategy': 642,
#   'Survival': 323,
#   'Score Attack': 304,
#   '1980s': 285,
#   'Assassin': 248,
#   'Nostalgia': 206}}
